# %%
#importing numpy
import numpy as np

# %%
#creating list of 5 mpg, horsepower and accelaration values

car_attr=[[18,15,18,16,17],[130,165,150,150,140],[307,350,318,304,302]]
car_attr_arr=np.array(car_attr)
car_attr_arr
# Out:
# array([[ 18,  15,  18,  16,  17],
#        [130, 165, 150, 150, 140],
#        [307, 350, 318, 304, 302]])

# %%
car_attr_arr.shape
# Out:
# (3, 5)

# %%
# find datatype and change dtype

car_attr_arr.dtype
# Out:
# dtype('int32')

# %%
car_attr_arr_float= np.array(car_attr_arr,dtype='float')
car_attr_arr_float
car_attr_arr_float.dtype
# Out:
# dtype('float64')

# %%
# Find horsepowers which are greater than 150

car_attr_arr[1]
# Out:
# array([130, 165, 150, 150, 140])

# %%
# where gives only index position not values
x=np.where(car_attr_arr[1] >=150)
x
# Out:
# (array([1, 2, 3], dtype=int64),)

# %%
car_attr_arr[1][x]
# Out:
# array([165, 150, 150])

# %%
# create new array with horsepower  greater than 135

filter_arr= car_attr_arr[1]>135
filter_arr
# Out:
# array([False,  True,  True,  True,  True])

# %%
new_arr=car_attr_arr[1][filter_arr]
new_arr
# Out:
# array([165, 150, 150, 140])

# %%
## sort the values of horsepower
# np.sort not modify original array
print("original array:",car_attr_arr[1])
print("sorted array:",np.sort(car_attr_arr[1]))
print("original array after sorting:",car_attr_arr[1])
# Out:
# original array: [130 165 150 150 140]
# sorted array: [130 140 150 150 165]
# original array after sorting: [130 165 150 150 140]

# %%
# arr.sort() sort orinial array also

print("original array:",car_attr_arr[1])
car_attr_arr.sort()
print("original array after sorting:",car_attr_arr[1])
# Out:
# original array: [130 165 150 150 140]
# original array after sorting: [130 140 150 150 165]

# %%
## problem Statement

arr=[[1,6012],[2,7079],[3,6886],[4,7230],[5,4598],[6,5564],[7,6971],[8,7763],[9,8032],[10,9569]]
arr_steps=np.array(arr)
arr_steps
# Out:
# array([[   1, 6012],
#        [   2, 7079],
#        [   3, 6886],
#        [   4, 7230],
#        [   5, 4598],
#        [   6, 5564],
#        [   7, 6971],
#        [   8, 7763],
#        [   9, 8032],
#        [  10, 9569]])

# %%
arr_steps.shape
# Out:
# (10, 2)

# %%
for i in range(0,10):
    j=1
    arr_steps[i][j]=arr_steps[i][j]+2000

# %%
arr_steps
# Out:
# array([[    1,  8012],
#        [    2,  9079],
#        [    3,  8886],
#        [    4,  9230],
#        [    5,  6598],
#        [    6,  7564],
#        [    7,  8971],
#        [    8,  9763],
#        [    9, 10032],
#        [   10, 11569]])

# %%
for i in range(0,10):
    j = 1
    if arr_steps[i][j] > 9000:
        print(np.array(arr_steps[i],arr_steps[i][j]))
        
    else:
        pass
# Out:
# [   2 9079]
# [   4 9230]
# [   8 9763]
# [    9 10032]
# [   10 11569]

# %%
## working on car dataset

import pandas as pd
cars_df=pd.read_csv(r"C:\Users\swati.sharma12\Downloads\Data Science\PythonForDataScienceCodeData\auto_mpg.csv")

# %%
cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars_df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
cars_df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
## drop Null values from horsepower column
## dropna delete all rows with NA values.

## inplace makes changes is original dataframe, means none value is deleted from original dataframe.

cars_df.dropna(inplace = True)
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
# it display data in dataframe format

cars_df[['name']]
# Out:
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [392 rows x 1 columns]

# %%
## it display data in series form

cars_df['name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 392, dtype: object

# %%
cars_df[['name','origin','model_year','mpg']]
# Out:
#                           name  origin  model_year   mpg
# 0    chevrolet chevelle malibu     usa          70  18.0
# 1            buick skylark 320     usa          70  15.0
# 2           plymouth satellite     usa          70  18.0
# 3                amc rebel sst     usa          70  16.0
# 4                  ford torino     usa          70  17.0
# ..                         ...     ...         ...   ...
# 393            ford mustang gl     usa          82  27.0
# 394                  vw pickup  europe          82  44.0
# 395              dodge rampage     usa          82  32.0
# 396                ford ranger     usa          82  28.0
# 397                 chevy s-10     usa          82  31.0
#
# [392 rows x 4 columns]

# %%
#creating a subset using head
df_head=cars_df.head()

#setting name as custom index
df_head.set_index('name',inplace= True)
df_head
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa

# %%
##Access group of rows and columns by integer index

cars_df.iloc[2,1]
# Out:
# 8

# %%
cars_df.iloc[2,-1]
# Out:
# 'plymouth satellite'

# %%
cars_df.iloc[1:5,2:6]
# Out:
#    displacement  horsepower  weight  acceleration
# 1         350.0       165.0    3693          11.5
# 2         318.0       150.0    3436          11.0
# 3         304.0       150.0    3433          12.0
# 4         302.0       140.0    3449          10.5

# %%
## Access a group of rows and columns by custom index
df_head.loc['buick skylark 320':'amc rebel sst']
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0       165.0    3693
# plymouth satellite  18.0          8         318.0       150.0    3436
# amc rebel sst       16.0          8         304.0       150.0    3433
#
#                     acceleration  model_year origin
# name
# buick skylark 320           11.5          70    usa
# plymouth satellite          11.0          70    usa
# amc rebel sst               12.0          70    usa

# %%
cars_df.loc[0:5,['cylinders','horsepower','name']]
# Out:
#    cylinders  horsepower                       name
# 0          8       130.0  chevrolet chevelle malibu
# 1          8       165.0          buick skylark 320
# 2          8       150.0         plymouth satellite
# 3          8       150.0              amc rebel sst
# 4          8       140.0                ford torino
# 5          8       198.0           ford galaxie 500

# %%
cars_df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
##Problem statement : Retrieve details of all the cars built in year 72.


cars_df[cars_df['model_year']==72].head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
#
#     model_year  origin                   name
# 57          72   japan  toyota corona hardtop
# 58          72     usa     dodge colt hardtop
# 59          72  europe      volkswagen type 3
# 60          72     usa         chevrolet vega
# 61          72     usa    ford pinto runabout

# %%
##Problem statement : Retrieve details of all the cars built in Japan having 6 cylinders

cars_df.loc[(cars_df['origin'] == 'japan') & (cars_df['cylinders']==6)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 123  20.0          6         156.0       122.0    2807          13.5
# 210  19.0          6         156.0       108.0    2930          15.5
# 241  22.0          6         146.0        97.0    2815          14.5
# 333  32.7          6         168.0       132.0    2910          11.4
# 361  25.4          6         168.0       116.0    2900          12.6
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year origin               name
# 123          73  japan     toyota mark ii
# 210          76  japan     toyota mark ii
# 241          77  japan         datsun 810
# 333          80  japan      datsun 280-zx
# 361          81  japan    toyota cressida
# 362          81  japan  datsun 810 maxima

# %%
## Fuel efficient
# MPG > 29, Horsepower < 93.5,
#Weight < 2500

cars_df[(cars_df['mpg']>29) & (cars_df['horsepower'] < 93.5) & (cars_df['weight'] < 2500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0        70.0    2074          19.5
# 52   30.0          4          88.0        76.0    2065          14.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# ..    ...        ...           ...         ...     ...           ...
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year  origin                 name
# 51           71  europe          peugeot 304
# 52           71  europe            fiat 124b
# ...

# %%
## Muscle cars
# Displacement >262, Horsepower > 126, Weight in range[2800, 3600]

cars_df[(cars_df['displacement'] > 262) & (cars_df['horsepower'] > 126) & (cars_df['weight']>=2800) & (cars_df['weight']<=3600)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# ...

# %%
# SUV
# Horsepower > 140 , Weight > 4500

cars_df[(cars_df['horsepower'] > 140) & (cars_df['weight'] > 4500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 25   10.0          8         360.0       215.0    4615          14.0
# 28    9.0          8         304.0       193.0    4732          18.5
# 42   12.0          8         383.0       180.0    4955          11.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 67   11.0          8         429.0       208.0    4633          11.0
# 68   13.0          8         350.0       155.0    4502          13.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 94   13.0          8         440.0       215.0    4735          11.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 104  12.0          8         400.0       167.0    4906          12.5
# 105  13.0          8         360.0       170.0    4654          13.0
# ...

# %%
# Racecar
# Weight <2223, acceleration > 17

cars_df[(cars_df['weight']<2223) & (cars_df['acceleration'] > 17)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19   26.0          4          97.0        46.0    1835          20.5
# 51   30.0          4          79.0        70.0    2074          19.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 55   27.0          4          97.0        60.0    1834          19.0
# 56   26.0          4          91.0        70.0    1955          20.5
# 79   26.0          4          96.0        69.0    2189          18.0
# 102  26.0          4          97.0        46.0    1950          21.0
# 117  29.0          4          68.0        49.0    1867          19.5
# 129  31.0          4          79.0        67.0    1950          19.0
# 131  32.0          4          71.0        65.0    1836          21.0
# 145  32.0          4          83.0        61.0    2003          19.0
# 181  33.0          4          91.0        53.0    1795          17.5
# ...

# %%
#Problem Statement:
#Consider the scenario where the board of XYZ custom cars wants to know about
#minimum and maximum of all the numerical columns.


list1=[col for col in cars_df.columns if cars_df[col].dtype in ['float','int64']]
cars_df[list1].agg(['min','max'])
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# min   9.0          3          68.0        46.0    1613           8.0
# max  46.6          8         455.0       230.0    5140          24.8
#
#      model_year
# min          70
# max          82

# %%
#Problem statement:
#How many cars belong to each year?

cars_df.groupby(['model_year']).count()[['name']]
# Out:
#             name
# model_year
# 70            29
# 71            27
# 72            28
# 73            40
# 74            26
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            27
# 81            28
# 82            30

# %%
#Problem Statement: 
#Some senior engineers in XYZ custom cars want to understand 
#about the effect of model year and number of cylinders on horsepower.


#Creating a DataFrame grouped on cylinders and model_year and finding mean, min and max of horsepower
grouped_multiple=cars_df.groupby(['cylinders', 'model_year']).agg({'horsepower':['mean','min','max']})

#Naming columns in grouped DataFrame

grouped_multiple.columns=['hp_mean','hp_min','hp_max']
grouped_multiple=grouped_multiple.reset_index()


grouped_multiple.head()
# Out:
#    cylinders  model_year     hp_mean  hp_min  hp_max
# 0          3          72   97.000000    97.0    97.0
# 1          3          73   90.000000    90.0    90.0
# 2          3          77  110.000000   110.0   110.0
# 3          3          80  100.000000   100.0   100.0
# 4          4          70   87.714286    46.0   113.0

# %%
#Problem statement: 
#The engineers at XYZ Custom Cars want to know about the
#relationship between model year and acceleration of cars.

cars_df.groupby(['model_year']).mean().sort_values('acceleration',ascending=False)[['acceleration']]
# Out:
#             acceleration
# model_year
# 80             17.018519
# 82             16.510000
# 81             16.325000
# 74             16.173077
# 75             16.050000
# 76             15.941176
# 79             15.813793
# 78             15.805556
# 77             15.435714
# 72             15.125000
# 71             15.000000
# 73             14.312500
# 70             12.948276

# %%
#The engineers at XYZ Custom Cars want to know the frequency distribution 
#of different number of cylinders across different years.

pd.crosstab(cars_df['model_year'], cars_df['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  12  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   6   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  23  1   2   0
# 81          0  20  0   7   1
# 82          0  27  0   3   0

# %%
## A scatter plot to visualize the trend of acceleration in different years.

cars_df.plot(x='model_year', y='acceleration', marker='o', kind='scatter')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='acceleration'>

# %%
## A bar plot to visualize mean acceleration in different years.

cars_df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');

# %%
## A histogram to visualize the frequency distribution of cylinders

cars_df['cylinders'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## scatter plot to visualize the relationship between weight and mpg.


cars_df.plot(x='weight', y='mpg', kind='scatter')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
cars_df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cylinders'>

# %%
## Rainfall Dataset EDA
#1: Import the data into Python environment as a Pandas DataFrame.

df=pd.read_csv(r'C:\Users\swati.sharma12\Downloads\Data Science\rainfall.csv')

# %%
df.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
# 2.Check for missing values, if any and drop the corresponding rows. 
df.isnull().sum()
# Out:
# STATE_UT_NAME    0
# DISTRICT         0
# JAN              0
# FEB              0
# MAR              0
# APR              0
# MAY              0
# JUN              0
# JUL              0
# AUG              0
# SEP              0
# OCT              0
# NOV              0
# DEC              0
# ANNUAL           0
# Jan-Feb          0
# Mar-May          0
# Jun-Sep          0
# Oct-Dec          0
# dtype: int64

# %%
# 3: Find the district that gets the highest annual rainfall.

max=df['ANNUAL'].max()

# %%
df[df['ANNUAL']==max]['DISTRICT']
# Out:
# 55    TAMENGLONG
# Name: DISTRICT, dtype: object

# %%
top_5_state=df.nlargest(5,'ANNUAL')[['STATE_UT_NAME']]

# %%
top_5_state
# Out:
#          STATE_UT_NAME
# 55             MANIPUR
# 47           MEGHALAYA
# 46           MEGHALAYA
# 12   ARUNACHAL PRADESH
# 598          KARNATAKA

# %%
df.columns
# Out:
# Index(['STATE_UT_NAME', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
#        'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df.drop(['Jan-Feb','Mar-May', 'Jun-Sep', 'Oct-Dec'],axis=1,inplace=True)

# %%
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
pivot1 = pd.pivot_table(data=df, index='STATE_UT_NAME', values=['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
       'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'], aggfunc='mean')
pivot1
# Out:
#                                     APR         AUG         DEC        FEB  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   86.966667  385.300000  159.733333  33.266667
# ANDHRA PRADESH                19.873913  179.426087   15.565217   7.352174
# ARUNACHAL PRADESH            275.162500  378.600000   35.956250  93.293750
# ASSAM                        181.266667  377.370370   11.440741  31.714815
# BIHAR                         16.865789  289.481579    5.786842   9.278947
# CHANDIGARH                    14.800000  287.500000   23.400000  38.900000
# CHATISGARH                    13.116667  375.338889    5.811111  10.472222
# DADAR NAGAR HAVELI             0.000000  655.900000    0.000000   0.300000
# DAMAN AND DUI                  0.100000  394.600000    0.450000   0.500000
# DELHI                          8.900000  245.500000    8.600000  16.300000
# GOA                            7.800000  683.800000   10.200000   0.050000
# ...

# %%
df.groupby('STATE_UT_NAME').count()[['DISTRICT']]
# Out:
#                              DISTRICT
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS         3
# ANDHRA PRADESH                     23
# ARUNACHAL PRADESH                  16
# ASSAM                              27
# BIHAR                              38
# CHANDIGARH                          1
# CHATISGARH                         18
# DADAR NAGAR HAVELI                  1
# DAMAN AND DUI                       2
# DELHI                               9
# GOA                                 2
# GUJARAT                            26
# HARYANA                            21
# HIMACHAL                           12
# JAMMU AND KASHMIR                  22
# JHARKHAND                          24
# KARNATAKA                          30
# KERALA                             14
# LAKSHADWEEP                         1
# MADHYA PRADESH                     50
# MAHARASHTRA                        35
# MANIPUR                             9
# MEGHALAYA                           7
# ...

# %%
pivot1 = pd.pivot_table(data=df, index='STATE_UT_NAME', values=[ 'DISTRICT','MAY'], aggfunc='max')
pivot1
# Out:
#                                    DISTRICT    MAY
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  374.4
# ANDHRA PRADESH                WEST GODAVARI   96.6
# ARUNACHAL PRADESH                WEST SIANG  453.0
# ASSAM                         UDALGURI(DARA  604.0
# BIHAR                        WEST CHAMPARAN  155.7
# CHANDIGARH                       CHANDIGARH   30.1
# CHATISGARH                          SURGUJA   38.6
# DADAR NAGAR HAVELI                      DNH    7.4
# DAMAN AND DUI                           DIU    7.4
# DELHI                            WEST DELHI   19.3
# GOA                               SOUTH GOA   94.3
# GUJARAT                              VALSAD   12.5
# HARYANA                         YAMUNANAGAR   27.9
# HIMACHAL                                UNA   91.7
# JAMMU AND KASHMIR                  UDHAMPUR  111.4
# JHARKHAND                    WEST SINGHBHUM   86.1
# KARNATAKA                            YADGIR  193.8
# ...

# %%
## Visualization on Cars MPG Data
##Some customers of XYZ Custom Cars are interested in the
##mileage range of the cars that are restored by the company.
##They also want to compare the distribution of average mileage
##and city mileage (25% less than the average mileage). 

import matplotlib.pyplot as plt
fig=plt.figure(figsize=[6,6])
ax=fig.add_axes([0,0,1,1])
ax.set_title('Distribution of Milege')
ax.boxplot(cars_df['mpg'])
plt.show();

# %%
cars_df['city_milege']=cars_df['mpg']*0.75
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  city_milege
# 0          70    usa  chevrolet chevelle malibu        13.50
# 1          70    usa          buick skylark 320        11.25
# 2          70    usa         plymouth satellite        13.50
# 3          70    usa              amc rebel sst        12.00
# 4          70    usa                ford torino        12.75

# %%
mpg_list=[cars_df['mpg'],cars_df['city_milege']]
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[6,5])
ax = fig.add_axes([0,0,1,1])
ax.set_title('Distribution of Average MPG vs City MPG')
ax.set_ylabel('Milege per gallon')

ax.boxplot(mpg_list, widths = 0.5)
plt.show();

# %%
## The engineers at XYZ Custom Cars want to infer the 
##correlation between horsepower and mileage. 

import matplotlib.pyplot as plt
fig = plt.figure(figsize=[10,5])
ax = fig.add_axes([0,0,1,1])
ax.scatter(cars_df['horsepower'],cars_df['mpg'])
ax.set_title("Scatter plot of horsepower and milege", fontsize=16)
ax.set_ylabel("Milege per gallon", fontsize=12)
ax.set_xlabel("Horsepower", fontsize=12)
plt.show();

# %%
#Model Building
cars_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# city_milege     0
# dtype: int64

# %%
## Creating matrix of predicators

X=cars_df.iloc[:, 1:8]

##Creating Target

Y=cars_df.iloc[:,0]

# %%
X=pd.get_dummies(X)
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin_europe  origin_japan  origin_usa
# ...

# %%
## Divide data into Train and Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
## Applying standard scaler on the data

from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit_transform(X_train)
scale.transform(X_test);

# %%
#Importing and fitting the model on training set

from sklearn.linear_model import LinearRegression
reg = LinearRegression()

#fitting the model on training data:

reg.fit(X_train, y_train)

#Checking the coefficient(slope) and intercept.
#m represents the coefficient and c represents the intercept

m=reg.coef_
c=reg.intercept_
m,c
# Out:
# (array([-0.38946904,  0.02158376, -0.01237154, -0.00700083,  0.12954429,
#          0.76774449,  0.83388251,  0.71982383, -1.55370633]),
#  -16.20312300058094)

# %%
#Predicting the target: mpg against the predictors in the training data set
#Predicted data stored in y_pred_train

y_pred_train = reg.predict(X_train)

#Predicting the target: mpg against the predictors in the testing data set
#Predicted data stored in y_pred_test

y_pred_test = reg.predict(X_test)

# %%
y_pred_test
# Out:
# array([25.51469604, 25.27886826, 10.53305685, 32.15477571, 32.95814026,
#        23.43992958, 34.21485266, 26.88615822, 20.23865435, 26.51556003,
#        28.55590056, 13.70730486, 24.86251701,  8.78102974, 16.82256734,
#        32.92133689, 26.61239728, 12.68417729, 26.27106596, 26.86332078,
#        20.99953477, 17.83198525, 23.53930949, 26.91428864, 32.56194353,
#        11.23834236, 28.62475595, 25.45513011, 22.92977219, 14.89347866,
#        22.18050151, 30.74416878, 24.77460688, 29.027514  , 21.77982546,
#        29.18586549, 28.24585686, 12.25338166, 14.8345176 , 10.63112153,
#        14.01825216, 34.3497955 , 30.51149418, 13.54998863, 31.61464295,
#        15.50609429, 29.91056317, 10.62060468, 17.48901497, 22.13984222,
#        27.55159048, 15.38444954,  8.3289872 , 22.92948054, 32.35007905,
#        27.08711398, 26.11439538, 20.75648743, 31.54863388, 24.08580553,
#        18.92135439, 28.15084321, 31.99809453, 10.58425642, 26.57587978,
# ...

# %%
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  city_milege
# 0          70    usa  chevrolet chevelle malibu        13.50
# 1          70    usa          buick skylark 320        11.25
# 2          70    usa         plymouth satellite        13.50
# 3          70    usa              amc rebel sst        12.00
# 4          70    usa                ford torino        12.75

# %%
# define input
new_input = [[8,307.0,130.0,3504,12.0,70,0,0,1]]
new_output = reg.predict(new_input)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_output
# Out:
# array([14.9110827])

# %%
# define input
new_input = [[8,302.0,140.0,3449,10.5,70,0,0,1]]
new_output = reg.predict(new_input)
new_output
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14.87017754])

# %%
# Prediction Accuracy in term of how close is the predicted value of target: mpg
#for training

from sklearn.metrics import r2_score
r2_S= r2_score(y_train, y_pred_train)
r2_S
# Out:
# 0.8194239716903474

# %%
from sklearn.metrics import r2_score
r2_S= r2_score(y_test, y_pred_test)
r2_S
# Out:
# 0.8387519287083123

# %% [markdown]
# ## KNN Classifier

# %%
cars_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  city_milege
# 0          70    usa  chevrolet chevelle malibu        13.50
# 1          70    usa          buick skylark 320        11.25
# 2          70    usa         plymouth satellite        13.50
# 3          70    usa              amc rebel sst        12.00
# 4          70    usa                ford torino        12.75

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
X1=cars_df.iloc[:, 0:8]
Y1=cars_df.iloc[:,8]

# %%
X1=pd.get_dummies(X1)
X1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin_europe  origin_japan  origin_usa
# 0            70              0             0           1
# ...

# %%
X1.shape
# Out:
# (392, 10)

# %%
Y1.shape
# Out:
# (392,)

# %%
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1,Y1, test_size=0.25, random_state=5)

# %%
knn = KNeighborsClassifier(n_neighbors = 4)
knn.fit(X1_train, Y1_train)
y1_pred = knn.predict(X1_test)
print(y1_pred)
# Out:
# ['buick skylark 320' 'chrysler lebaron medallion'
#  'buick opel isuzu deluxe' 'chevrolet chevette'
#  'chevrolet chevelle concours (sw)' 'peugeot 504' 'ford maverick'
#  'datsun 200-sx' 'buick century luxus (sw)' 'amc hornet'
#  'cadillac seville' 'dodge omni' 'datsun 210 mpg' 'ford galaxie 500'
#  'audi 5000' 'chrysler new yorker brougham' 'buick opel isuzu deluxe'
#  'amc ambassador brougham' 'ford fairmont (man)' 'audi 5000' 'honda civic'
#  'amc matador' 'honda civic' 'datsun 310 gx' 'amc concord'
#  'chevrolet chevette' 'ford fiesta' 'chevrolet chevette' 'chevrolet vega'
#  'fiat 128' 'datsun 510 (sw)' 'ford fiesta' 'datsun b-210' 'honda civic'
#  'buick lesabre custom' 'buick skyhawk' 'chevrolet chevette'
#  'buick electra 225 custom' 'ford fiesta' 'ford fiesta'
#  'chevrolet chevette' 'chevrolet chevette' 'buick century'
#  'buick estate wagon (sw)' 'chevrolet camaro' 'datsun 200-sx' 'audi 4000'
#  'audi 100ls' 'buick lesabre custom' 'dodge omni' 'ford fiesta'
# ...

# %%
# define input
new_input1 = [[17.0, 8, 302.0, 140.0, 3449, 10.5, 70, 0, 0, 1]]
new_output1 = knn.predict(new_input1)
new_output1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array(['amc rebel sst'], dtype=object)

# %%
scores = cross_val_score(knn, X1, Y1, cv=5, scoring='accuracy')
print(scores)
# Out:
# [0.02531646 0.02531646 0.01282051 0.02564103 0.        ]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
print(scores.mean())
# Out:
# 0.017818889970788704
